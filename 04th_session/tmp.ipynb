# %%
import cv2
import matplotlib.pyplot as pt

image = cv2.imread('./images/jozveh_sample-01.jpg', 0)
_, binary = cv2.threshold(image, 85, 255, cv2.THRESH_BINARY)
binary = [~i for i in binary]

pt.figure(figsize=[7, 10])
pt.subplot(111); pt.imshow(binary, 'gray'); pt.title('Image');
