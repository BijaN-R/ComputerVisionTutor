# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt 

image = cv2.imread('./images/noon_khameii.jpg')
plt.imshow(image[:,:,::-1])

# %%
height, width = image.shape[:2]

cropped = image[400:700, 535:1020]
plt.imshow(cropped[..., ::-1])
