# %%
import cv2
import numpy as np

# %%
img = cv2.imread('./images/noon_khameii.jpg')

cv2.imshow('Its a wow!', img)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
type(img)
# Out:
# numpy.ndarray

# %%
print(img.shape)
# Out:
# (300, 300, 3)

# %%
cv2.imwrite('./images/noon_khameii_2.jpg', img)
cv2.imwrite('./images/noon_khameii_2.png', img)
# Out:
# True

# %%
import matplotlib.pyplot as plt
plt.imshow(img[:,:,::-1])

# %%
rgb_image = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(rgb_image)

# %%
gry_image = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
rgb_image = cv2.cvtColor(gry_image,cv2.COLOR_BGR2RGB)
plt.imshow(rgb_image)

# %%
img = cv2.imread('./images/noon_khameii.jpg')
img[200:400, 400:800, :] = [255, 80, 0]
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
cv2.imwrite('./images/noon_khameii_out.jpg', img)
# Out:
# True
