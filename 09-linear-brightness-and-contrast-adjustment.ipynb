# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

image = cv2.imread('./images/noon_khameii.jpg')

alpha = float(input('Enter the alpha value (between 0 , 3):'))
beta = int(input('Enter the beta value (between -100 , 100):'))

newImage = cv2.convertScaleAbs(image, alpha= alpha, beta= beta)

plt.figure(figsize=[15,5])
plt.subplot(121);plt.imshow(image[..., ::-1]);plt.title('Original');
plt.subplot(122);plt.imshow(newImage[..., ::-1]);plt.title('High Contrast');
# Out:
# Enter the alpha value (between 0 , 3):1.5
# Enter the beta value (between -100 , 100):-50

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

image = cv2.imread('./images/noon_khameii.jpg')

newImage2 = np.zeros(image.shape, image.dtype)

alpha = float(input('Enter the alpha value (between 0 , 3):'))
beta = int(input('Enter the beta value (between -100 , 100):'))

for y in range(image.shape[0]):
    for x in range(image.shape[1]):
        for c in range(image.shape[2]):
            newImage2 [y, x, c] = np.clip(alpha * image[y, x, c] + beta, 0, 255)

plt.figure(figsize=[15,5])
plt.subplot(121);plt.imshow(image[..., ::-1]);plt.title('Original');
plt.subplot(122);plt.imshow(newImage2[..., ::-1]);plt.title('High Contrast');
# Out:
# Enter the alpha value (between 0 , 3):1.5
# Enter the beta value (between -100 , 100):-50

# %%
grayImage = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
grayNewImage = cv2.cvtColor(newImage, cv2.COLOR_BGR2GRAY)
grayNewImage2 = cv2.cvtColor(newImage2, cv2.COLOR_BGR2GRAY)

# %%
plt.figure(figsize=[15,5])
plt.subplot(131);plt.hist(grayImage.ravel(), 256, [0, 256]);plt.title('Original');
plt.subplot(132);plt.hist(grayNewImage.ravel(), 256, [0, 256]);plt.title('NewImage');
plt.subplot(133);plt.hist(grayNewImage2.ravel(), 256, [0, 256]);plt.title('Newimage2');

# %%
# ?plt.hist
